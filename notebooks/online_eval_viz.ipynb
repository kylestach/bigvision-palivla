# %%
import numpy as np
import os
import matplotlib.pyplot as plt 
from PIL import Image
import io
# !pip install mediapy
import mediapy

# %%
PATH = "/nfs/nfs2/users/riadoshi/eval_logs/042325-17:35"

# %%
image_files = os.listdir(f"{PATH}/images/")
image_files.sort(key=lambda x: int(x[x.index('_')+1 : x.index('.')]))

images = []
for file in image_files:
    pil_img  = Image.open(f"{PATH}/images/{file}")
    images.append(np.array(pil_img))

# %%
info = np.load(f'{PATH}/info.npy', allow_pickle=True).item()
actions, cots = info['actions'], info['cots']
actions
# Out:
# [array([ 0.01932762, -0.02      ,  0.00731952, -0.05043987, -0.03586185,
#         -0.03828531,  0.        ]),
#  array([-0.00455992, -0.00173738, -0.01474736, -0.02062789,  0.03678746,
#         -0.05223798,  0.        ]),
#  array([-1.03393470e-02, -3.77945538e-03,  5.30795801e-03, -4.65380851e-04,
#         -5.49584567e-03,  5.09852166e-02,  1.05000000e+00]),
#  array([ 2.00000000e-02, -2.00000000e-02,  4.60549506e-03, -4.88331658e-02,
#          2.06069914e-02, -5.66858894e-04,  1.05000000e+00]),
#  array([-0.0117842 ,  0.01103405,  0.02      ,  0.0021231 ,  0.01787892,
#         -0.04526164,  0.        ]),
#  array([-0.00610871, -0.00344996, -0.01704462,  0.02711474,  0.06117105,
#         -0.01461489,  1.05      ]),
#  array([0.01534718, 0.02      , 0.01109233, 0.02773989, 0.00322409,
#         0.01952003, 1.05      ]),
#  array([-2.25353203e-04, -1.56005743e-02, -8.82800438e-03, -6.60415374e-02,
#         -2.57493846e-02,  2.30081930e-02,  1.05000000e+00]),
#  array([ 0.00021759,  0.00012508, -0.00017108, -0.00016171, -0.00025249,
#          0.00025158,  0.        ]),
#  array([-0.01234619,  0.01867627,  0.01987642, -0.04862662,  0.00328107,
#         -0.11261768,  0.        ]),
#  array([-0.00122727, -0.00766702, -0.01388247,  0.00634489,  0.0119821 ,
#         -0.03215109,  1.05      ]),
#  array([-0.00267213, -0.00454594, -0.01388247, -0.01869092, -0.00548639,
#         -0.04259192,  1.05      ]),
#  array([-0.00367705,  0.00200452,  0.00055882,  0.07608987,  0.01517002,
#          0.04925297,  0.        ]),
#  array([ 0.00166244,  0.01430079,  0.00589898, -0.00240235, -0.03622665,
#         -0.02517476,  1.05      ]),
#  array([-0.00088826, -0.02      , -0.01215659, -0.01024736, -0.03585239,
#         -0.02948137,  0.13921053]),
#  array([ 7.11496612e-03, -2.00000000e-02, -4.60682772e-04, -5.89629834e-02,
#         -6.87891511e-03,  3.17884569e-02,  1.05000000e+00]),
#  array([ 0.02      , -0.01202553, -0.02      , -0.12259338, -0.0910999 ,
#          0.01162989,  0.        ]),
#  array([ 0.00021759,  0.00012508, -0.00017108, -0.00016171, -0.00025249,
#          0.00025158,  0.        ]),
#  array([-0.00333503, -0.00237517, -0.00637613, -0.02937513, -0.00201927,
#          0.06154508,  0.        ]),
#  array([ 0.02      , -0.01669655, -0.01403708, -0.00532989,  0.03998484,
#         -0.00590631,  1.05      ]),
#  array([ 0.02      , -0.02      ,  0.01959463, -0.00308925,  0.04546933,
#          0.02125227,  1.05      ]),
#  array([-0.01566372,  0.02      ,  0.00763667,  0.03619224,  0.00777592,
#          0.03614242,  0.        ]),
#  array([ 0.01299832,  0.0094841 , -0.01158521,  0.00241799,  0.02353461,
#         -0.0259932 ,  1.05      ]),
#  array([ 3.21514482e-04, -1.69920963e-02, -7.67742186e-03, -3.55338780e-02,
#          2.52310455e-03,  2.51580728e-04,  1.05000000e+00]),
#  array([ 0.02      , -0.01078388,  0.010787  ,  0.03715622, -0.02681518,
#          0.04576481,  0.        ]),
#  array([ 1.88541563e-03,  3.07930876e-03, -2.33336177e-03,  4.71158706e-03,
#          4.33740695e-03,  2.51580728e-04,  1.05000000e+00]),
#  array([-0.00189018,  0.00277101, -0.00738782, -0.01183648, -0.0393765 ,
#          0.02649636,  1.05      ]),
#  array([ 0.01588803, -0.00190002,  0.01425448, -0.02739399, -0.02230142,
#         -0.01993067,  0.        ]),
#  array([-0.00534187,  0.00682121, -0.01620326,  0.0218936 , -0.02259954,
#         -0.01728462,  1.05      ]),
#  array([-0.00855247,  0.00652566,  0.02      ,  0.01448478,  0.0328891 ,
#         -0.01278728,  0.        ]),
#  array([-0.00055225, -0.02      ,  0.02      , -0.00894433,  0.11292281,
#         -0.08197093,  0.        ]),
#  array([ 0.00032151, -0.00252084,  0.0034432 ,  0.00208772,  0.01408506,
#         -0.0259932 ,  0.        ]),
#  array([ 0.00564589, -0.02      , -0.02      , -0.01346978,  0.03571222,
#         -0.17576247,  0.        ]),
#  array([-4.55992199e-03,  1.25082632e-04, -1.38824662e-02,  5.99704310e-03,
#          2.87209896e-02,  2.51580728e-04,  1.05000000e+00]),
#  array([ 4.40559369e-04,  1.52936309e-03, -7.46375728e-04, -2.38591023e-02,
#          2.38518872e-02,  1.51180541e-02,  1.05000000e+00]),
#  array([ 0.00444522,  0.00324195,  0.01671817, -0.00016171, -0.0449752 ,
#         -0.05748207,  0.        ]),
#  array([ 2.17586217e-04, -3.61681723e-03, -6.37612877e-03,  4.06007310e-03,
#          2.20582573e-03,  5.47199196e-03,  9.56773919e-01]),
#  array([ 0.00700193, -0.00564192, -0.01156557,  0.00928121,  0.00150484,
#         -0.01112673,  0.7731483 ]),
#  array([-0.00789257, -0.02      ,  0.00011461, -0.02971418,  0.06682673,
#          0.05274114,  0.        ]),
#  array([-0.00311507, -0.00190002, -0.01734994, -0.01834308,  0.00289736,
#          0.00025158,  0.        ]),
#  array([-0.00133421,  0.00729215,  0.00733525,  0.01638636, -0.02644092,
#         -0.04956825,  0.        ]),
#  array([ 0.01333733, -0.01063822,  0.00415738, -0.01381762, -0.09945503,
#          0.12358534,  0.        ]),
#  array([ 0.00166244, -0.00719186, -0.01244619,  0.0021231 ,  0.00257063,
#          0.02649636,  1.05      ]),
#  array([-0.00277605,  0.01851364,  0.02      , -0.03359691, -0.02436632,
#         -0.12142162,  0.        ]),
#  array([ 0.00232535,  0.02      ,  0.01338959,  0.01314636, -0.04461985,
#          0.06585169,  0.        ]),
#  array([ 1.71159288e-02,  1.25082632e-04, -9.55400620e-03, -2.25648603e-02,
#         -2.85819537e-02,  7.22791527e-03,  2.89210526e-01]),
#  array([ 0.02      , -0.01138773, -0.00277367,  0.00439913, -0.01494539,
#          0.0843017 ,  1.05      ]),
#  array([ 0.00021759,  0.00012508, -0.00017108, -0.00016171, -0.00025249,
#          0.00025158,  0.        ]),
#  array([ 0.0091097 , -0.00111656, -0.00723711, -0.00567773, -0.00618738,
#         -0.00763856,  1.05      ]),
#  array([ 0.00333027,  0.00557957, -0.01172019, -0.02420694,  0.01722546,
#          0.08165565,  1.11913275])]

# %%
mediapy.show_video(images, fps=2)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="224" height="224" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
from palivla.visualizations.chain_of_thought import parse_cot_string, visualize_trajectory, TrajectoryData

def create_viz(
    image: np.ndarray,
    pred_trajectory: TrajectoryData,
    prompt_str: str,
) -> np.ndarray:
    """Create a side-by-side visualization comparing predicted and target trajectories.

    Args:
        image: Input image to show in both panels
        pred_trajectory: Predicted trajectory from the model
        target_trajectory: Target/ground truth trajectory
        prompt_str: Text prompt to show as subtitle

    Returns:
        PIL Image containing the rendered figure
    """
    # Create figure with two subplots side by side
    fig, (ax1) = plt.subplots(1, 1, figsize=(6, 6))

    # Remove <pad> from prompt string
    fig.suptitle(prompt_str, wrap=True)

    # Plot predicted and target trajectories
    visualize_trajectory(ax1, image, pred_trajectory, "Predicted")

    # Adjust layout and convert to image
    plt.tight_layout()

    # Convert figure to PIL Image
    buf = io.BytesIO()
    plt.savefig(buf, format="png")
    buf.seek(0)
    img = Image.open(buf)
    plt.close(fig)

    return img

comp_imgs = []
for image, cot in zip(images, cots):
    pred_trajectory_data = parse_cot_string(cot)
    comparison_image = create_viz(
        image, pred_trajectory_data, "put mushroom on top of the pot"
    )
    comp_imgs.append(np.array(comparison_image)[:,:,:3])
mediapy.show_video(comp_imgs, fps=1)
# Out:
# 2025-04-22 18:42:00.682530: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745347320.701092  906326 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745347320.706784  906326 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745347320.720623  906326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745347320.720640  906326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745347320.720642  906326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745347320.720643  906326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="600" height="600" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
mediapy.show_video(comp_imgs, fps=1)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="600" height="600" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
# !sudo apt install ffmpeg -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libatasmart4 libblockdev-fs2 libblockdev-loop2 libblockdev-part-err2
#   libblockdev-part2 libblockdev-swap2 libblockdev-utils2 libblockdev2
#   libmm-glib0 libnspr4 libnss3 libparted-fs-resize0 libudisks2-0
#   usb-modeswitch usb-modeswitch-data
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   i965-va-driver intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0
#   libavc1394-0 libavcodec58 libavdevice58 libavfilter7 libavformat58
#   libavresample4 libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0
#   libcairo-gobject2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdc1394-22 libdrm-amdgpu1 libdrm-intel1 libdrm-nouveau2
#   libdrm-radeon1 libfftw3-double3 libflac8 libflite1 libgdk-pixbuf2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri
#   libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0 libgsm1 libiec61883-0
#   libigdgmm11 libjack-jackd2-0 liblilv-0-0 libllvm12 libmp3lame0 libmpg123-0
#   libmysofa1 libnorm1 libopenal-data libopenal1 libopenmpt0 libopus0
#   libpciaccess0 libpgm-5.2-0 libpostproc55 libpulse0 libraw1394-11 librsvg2-2
#   librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libtheora0 libtwolame0 libva-drm2 libva-x11-2
#   libva2 libvdpau1 libvidstab1.1 libvorbisenc2 libvpx6 libvulkan1 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwebpmux3
#   libx11-xcb1 libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-shape0 libxcb-sync1 libxcb-xfixes0
#   libxcursor1 libxfixes3 libxi6 libxkbcommon0 libxrandr2 libxshmfence1 libxss1
#   libxv1 libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0
#   mesa-va-drivers mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1
#   va-driver-all vdpau-driver-all
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin
#   lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg i965-va-driver intel-media-va-driver libaacs0 libaom0 libass9
#   libasyncns0 libavc1394-0 libavcodec58 libavdevice58 libavfilter7
#   libavformat58 libavresample4 libavutil56 libbdplus0 libbluray2 libbs2b0
#   libcaca0 libcairo-gobject2 libcdio-cdda2 libcdio-paranoia2 libcdio18
#   libchromaprint1 libcodec2-0.9 libdc1394-22 libdrm-amdgpu1 libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libfftw3-double3 libflac8 libflite1
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0 libgsm1
#   libiec61883-0 libigdgmm11 libjack-jackd2-0 liblilv-0-0 libllvm12 libmp3lame0
#   libmpg123-0 libmysofa1 libnorm1 libopenal-data libopenal1 libopenmpt0
#   libopus0 libpciaccess0 libpgm-5.2-0 libpostproc55 libpulse0 libraw1394-11
#   librsvg2-2 librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libtheora0 libtwolame0 libva-drm2 libva-x11-2
#   libva2 libvdpau1 libvidstab1.1 libvorbisenc2 libvpx6 libvulkan1 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwebpmux3
#   libx11-xcb1 libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-shape0 libxcb-sync1 libxcb-xfixes0
#   libxcursor1 libxfixes3 libxi6 libxkbcommon0 libxrandr2 libxshmfence1 libxss1
#   libxv1 libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0
#   mesa-va-drivers mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1
#   va-driver-all vdpau-driver-all
# 0 upgraded, 125 newly installed, 0 to remove and 297 not upgraded.
# Need to get 89.1 MB of archives.
# After this operation, 757 MB of additional disk space will be used.
# Get:1 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libaom0 amd64 1.0.0.errata1-3+deb11u1ubuntu0.1 [1161 kB]
# Get:2 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libva2 amd64 2.7.0-2 [53.5 kB]
# Get:3 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libva-drm2 amd64 2.7.0-2 [7044 B]
# Get:4 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxfixes3 amd64 1:5.0.3-2 [10.9 kB]
# Get:5 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libva-x11-2 amd64 2.7.0-2 [11.9 kB]
# Get:6 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libvdpau1 amd64 1.3-1ubuntu2 [25.6 kB]
# Get:7 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 ocl-icd-libopencl1 amd64 2.2.11-1ubuntu1 [30.3 kB]
# Get:8 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavutil56 amd64 7:4.2.7-0ubuntu0.1 [241 kB]
# Get:9 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libcodec2-0.9 amd64 0.9.2-2 [7886 kB]
# Get:10 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libgsm1 amd64 1.0.18-2 [24.4 kB]
# Get:11 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libmp3lame0 amd64 3.100-3 [133 kB]
# Get:12 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libopus0 amd64 1.3.1-0ubuntu1 [191 kB]
# Get:13 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libcairo-gobject2 amd64 1.16.0-4ubuntu1 [17.2 kB]
# Get:14 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdk-pixbuf2.0-common all 2.40.0+dfsg-3ubuntu0.5 [4628 B]
# Get:15 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdk-pixbuf2.0-0 amd64 2.40.0+dfsg-3ubuntu0.5 [169 kB]
# Get:16 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 librsvg2-2 amd64 2.48.9-1ubuntu0.20.04.4 [2313 kB]
# Get:17 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libshine3 amd64 3.1.1-2 [23.2 kB]
# Get:18 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libsnappy1v5 amd64 1.1.8-1build1 [16.7 kB]
# Get:19 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libspeex1 amd64 1.2~rc1.2-1.1ubuntu1.20.04.1 [53.2 kB]
# Get:20 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libsoxr0 amd64 0.1.3-2build1 [78.0 kB]
# Get:21 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libswresample3 amd64 7:4.2.7-0ubuntu0.1 [57.1 kB]
# Get:22 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15ubuntu2 [162 kB]
# Get:23 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libtwolame0 amd64 0.4.0-2 [47.6 kB]
# Get:24 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libvorbisenc2 amd64 1.3.6-2ubuntu1 [70.7 kB]
# Get:25 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libvpx6 amd64 1.8.2-1ubuntu0.3 [820 kB]
# Get:26 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libwavpack1 amd64 5.2.0-1ubuntu0.1 [77.3 kB]
# Get:27 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libwebpmux3 amd64 0.6.1-2ubuntu0.20.04.3 [19.5 kB]
# Get:28 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libx264-155 amd64 2:0.155.2917+git0a84d98-2 [521 kB]
# Get:29 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libx265-179 amd64 3.2.1-1build1 [1060 kB]
# Get:30 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libxvidcore4 amd64 2:1.3.7-1 [201 kB]
# Get:31 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libzvbi-common all 0.2.35-17 [32.5 kB]
# Get:32 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libzvbi0 amd64 0.2.35-17 [237 kB]
# Get:33 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavcodec58 amd64 7:4.2.7-0ubuntu0.1 [4878 kB]
# Get:34 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:35 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libavc1394-0 amd64 0.5.4-5 [16.2 kB]
# Get:36 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libass9 amd64 1:0.14.0-2 [88.0 kB]
# Get:37 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libbluray2 amd64 1:1.2.0-1 [138 kB]
# Get:38 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libchromaprint1 amd64 1.4.3-3build1 [37.6 kB]
# Get:39 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libgme0 amd64 0.6.2-1build1 [123 kB]
# Get:40 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libmpg123-0 amd64 1.25.13-1ubuntu0.2 [124 kB]
# Get:41 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libopenmpt0 amd64 0.4.11-1build1 [599 kB]
# Get:42 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libssh-gcrypt-4 amd64 0.9.3-2ubuntu2.5 [202 kB]
# Get:43 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavformat58 amd64 7:4.2.7-0ubuntu0.1 [985 kB]
# Get:44 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2build1 [10.2 kB]
# Get:45 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libflite1 amd64 2.1-release-3 [12.8 MB]
# Get:46 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libserd-0-0 amd64 0.30.2-1 [46.6 kB]
# Get:47 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libsord-0-0 amd64 0.16.4-1 [19.5 kB]
# Get:48 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libsratom-0-0 amd64 0.6.4-1 [16.9 kB]
# Get:49 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 liblilv-0-0 amd64 0.24.6-1ubuntu0.1 [40.6 kB]
# Get:50 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libmysofa1 amd64 1.0~dfsg0-1 [39.2 kB]
# Get:51 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libpostproc55 amd64 7:4.2.7-0ubuntu0.1 [55.0 kB]
# Get:52 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu1 [728 kB]
# Get:53 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libsamplerate0 amd64 0.1.9-2 [939 kB]
# Get:54 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 librubberband2 amd64 1.8.2-1build1 [89.4 kB]
# Get:55 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libswscale5 amd64 7:4.2.7-0ubuntu0.1 [157 kB]
# Get:56 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libvidstab1.1 amd64 1.1.0-2 [35.0 kB]
# Get:57 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libnorm1 amd64 1.5.8+dfsg2-2build1 [290 kB]
# Get:58 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libpgm-5.2-0 amd64 5.2.122~dfsg-3ubuntu1 [158 kB]
# Get:59 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libzmq5 amd64 4.3.2-2ubuntu1 [242 kB]
# Get:60 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavfilter7 amd64 7:4.2.7-0ubuntu0.1 [1085 kB]
# Get:61 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libcaca0 amd64 0.99.beta19-2.1ubuntu1.20.04.2 [203 kB]
# Get:62 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libcdio18 amd64 2.0.0-2ubuntu0.2 [59.4 kB]
# Get:63 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libcdio-cdda2 amd64 10.2+2.0.0-1 [17.6 kB]
# Get:64 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libcdio-paranoia2 amd64 10.2+2.0.0-1 [16.2 kB]
# Get:65 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libdc1394-22 amd64 2.2.5-2.1 [79.6 kB]
# Get:66 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libglvnd0 amd64 1.3.2-1~ubuntu0.20.04.2 [48.1 kB]
# Get:67 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libglapi-mesa amd64 21.2.6-0ubuntu0.1~20.04.2 [27.4 kB]
# Get:68 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-xcb1 amd64 2:1.6.9-2ubuntu1.6 [9448 B]
# Get:69 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-dri2-0 amd64 1.14-2 [6920 B]
# Get:70 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-dri3-0 amd64 1.14-2 [6552 B]
# Get:71 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-glx0 amd64 1.14-2 [22.1 kB]
# Get:72 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-present0 amd64 1.14-2 [5560 B]
# Get:73 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-sync1 amd64 1.14-2 [8884 B]
# Get:74 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-xfixes0 amd64 1.14-2 [9296 B]
# Get:75 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxshmfence1 amd64 1.3-1 [5028 B]
# Get:76 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxxf86vm1 amd64 1:1.1.4-1build1 [10.2 kB]
# Get:77 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-amdgpu1 amd64 2.4.107-8ubuntu1~20.04.2 [18.6 kB]
# Get:78 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libpciaccess0 amd64 0.16-0ubuntu1 [17.9 kB]
# Get:79 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-intel1 amd64 2.4.107-8ubuntu1~20.04.2 [60.3 kB]
# Get:80 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-nouveau2 amd64 2.4.107-8ubuntu1~20.04.2 [16.6 kB]
# Get:81 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-radeon1 amd64 2.4.107-8ubuntu1~20.04.2 [19.7 kB]
# Get:82 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libllvm12 amd64 1:12.0.0-3ubuntu1~20.04.5 [18.8 MB]
# Get:83 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libsensors-config all 1:3.6.0-2ubuntu1.1 [6052 B]
# Get:84 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libsensors5 amd64 1:3.6.0-2ubuntu1.1 [27.2 kB]
# Get:85 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libvulkan1 amd64 1.2.131.2-1 [93.3 kB]
# Get:86 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1-mesa-dri amd64 21.2.6-0ubuntu0.1~20.04.2 [11.0 MB]
# Get:87 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libglx-mesa0 amd64 21.2.6-0ubuntu0.1~20.04.2 [137 kB]
# Get:88 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libglx0 amd64 1.3.2-1~ubuntu0.20.04.2 [32.5 kB]
# Get:89 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1 amd64 1.3.2-1~ubuntu0.20.04.2 [85.8 kB]
# Get:90 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libiec61883-0 amd64 1.2.0-3 [24.3 kB]
# Get:91 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2ubuntu2 [267 kB]
# Get:92 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libopenal-data all 1:1.19.1-1 [162 kB]
# Get:93 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libsndio7.0 amd64 1.5.0-3 [24.5 kB]
# Get:94 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libopenal1 amd64 1:1.19.1-1 [492 kB]
# Get:95 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libasyncns0 amd64 0.8-6 [12.1 kB]
# Get:96 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libflac8 amd64 1.3.3-1ubuntu0.2 [103 kB]
# Get:97 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libsndfile1 amd64 1.0.28-7ubuntu0.3 [170 kB]
# Get:98 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libpulse0 amd64 1:13.99.1-1ubuntu3.13 [262 kB]
# Get:99 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-client0 amd64 1.18.0-1ubuntu0.1 [23.9 kB]
# Get:100 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-cursor0 amd64 1.18.0-1ubuntu0.1 [10.3 kB]
# Get:101 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-egl1 amd64 1.18.0-1ubuntu0.1 [5596 B]
# Get:102 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcursor1 amd64 1:1.2.0-2 [20.1 kB]
# Get:103 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxi6 amd64 2:1.7.10-0ubuntu1 [29.9 kB]
# Get:104 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxkbcommon0 amd64 0.10.0-1 [98.4 kB]
# Get:105 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxrandr2 amd64 2:1.5.2-0ubuntu1 [18.5 kB]
# Get:106 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxss1 amd64 1:1.2.3-1 [8140 B]
# Get:107 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-2.0-0 amd64 2.0.10+dfsg1-3 [407 kB]
# Get:108 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shape0 amd64 1.14-2 [5928 B]
# Get:109 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxv1 amd64 2:1.0.11-1 [10.7 kB]
# Get:110 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavdevice58 amd64 7:4.2.7-0ubuntu0.1 [74.3 kB]
# Get:111 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavresample4 amd64 7:4.2.7-0ubuntu0.1 [54.2 kB]
# Get:112 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 ffmpeg amd64 7:4.2.7-0ubuntu0.1 [1453 kB]
# Get:113 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libigdgmm11 amd64 20.1.1+ds1-1 [111 kB]
# Get:114 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 intel-media-va-driver amd64 20.1.1+dfsg1-1 [1764 kB]
# Get:115 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libaacs0 amd64 0.9.0-2 [50.1 kB]
# Get:116 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 libbdplus0 amd64 0.1.2-3 [47.3 kB]
# Get:117 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 libgdk-pixbuf2.0-bin amd64 2.40.0+dfsg-3ubuntu0.5 [14.1 kB]
# Get:118 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 librsvg2-common amd64 2.48.9-1ubuntu0.20.04.4 [9224 B]
# Get:119 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 libxcb-randr0 amd64 1.14-2 [16.3 kB]
# Get:120 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/universe amd64 mesa-va-drivers amd64 21.2.6-0ubuntu0.1~20.04.2 [2970 kB]
# Get:121 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 mesa-vdpau-drivers amd64 21.2.6-0ubuntu0.1~20.04.2 [3089 kB]
# Get:122 http://us-central2.gce.archive.ubuntu.com/ubuntu focal-updates/main amd64 mesa-vulkan-drivers amd64 21.2.6-0ubuntu0.1~20.04.2 [5788 kB]
# Get:123 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 i965-va-driver amd64 2.4.0-0ubuntu1 [924 kB]
# Get:124 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/universe amd64 va-driver-all amd64 2.7.0-2 [4020 B]
# Get:125 http://us-central2.gce.archive.ubuntu.com/ubuntu focal/main amd64 vdpau-driver-all amd64 1.3-1ubuntu2 [4596 B]
# Fetched 89.1 MB in 5s (19.2 MB/s)
# Extracting templates from packages: 100%
#
# 78Selecting previously unselected package libaom0:amd64.
# (Reading database ... 71518 files and directories currently installed.)
# Preparing to unpack .../000-libaom0_1.0.0.errata1-3+deb11u1ubuntu0.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libaom0:amd64 (1.0.0.errata1-3+deb11u1ubuntu0.1) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../001-libva2_2.7.0-2_amd64.deb ...
# Unpacking libva2:amd64 (2.7.0-2) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../002-libva-drm2_2.7.0-2_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.7.0-2) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../003-libxfixes3_1%3a5.0.3-2_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../004-libva-x11-2_2.7.0-2_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.7.0-2) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../005-libvdpau1_1.3-1ubuntu2_amd64.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking libvdpau1:amd64 (1.3-1ubuntu2) ...
# Selecting previously unselected package ocl-icd-libopencl1:amd64.
# Preparing to unpack .../006-ocl-icd-libopencl1_2.2.11-1ubuntu1_amd64.deb ...
# Unpacking ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../007-libavutil56_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavutil56:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libcodec2-0.9:amd64.
# Preparing to unpack .../008-libcodec2-0.9_0.9.2-2_amd64.deb ...
# Unpacking libcodec2-0.9:amd64 (0.9.2-2) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../009-libgsm1_1.0.18-2_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.18-2) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../010-libmp3lame0_3.100-3_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libmp3lame0:amd64 (3.100-3) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../011-libopus0_1.3.1-0ubuntu1_amd64.deb ...
# Unpacking libopus0:amd64 (1.3.1-0ubuntu1) ...
# Selecting previously unselected package libcairo-gobject2:amd64.
# Preparing to unpack .../012-libcairo-gobject2_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo-gobject2:amd64 (1.16.0-4ubuntu1) ...
# 7Progress: [  5%] [###.......................................................] 8Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../013-libgdk-pixbuf2.0-common_2.40.0+dfsg-3ubuntu0.5_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.40.0+dfsg-3ubuntu0.5) ...
# Selecting previously unselected package libgdk-pixbuf2.0-0:amd64.
# Preparing to unpack .../014-libgdk-pixbuf2.0-0_2.40.0+dfsg-3ubuntu0.5_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-0:amd64 (2.40.0+dfsg-3ubuntu0.5) ...
# Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../015-librsvg2-2_2.48.9-1ubuntu0.20.04.4_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking librsvg2-2:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../016-libshine3_3.1.1-2_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../017-libsnappy1v5_1.1.8-1build1_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.8-1build1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../018-libspeex1_1.2~rc1.2-1.1ubuntu1.20.04.1_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1.1ubuntu1.20.04.1) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../019-libsoxr0_0.1.3-2build1_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.3-2build1) ...
# Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../020-libswresample3_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libswresample3:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../021-libtheora0_1.1.1+dfsg.1-15ubuntu2_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu2) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../022-libtwolame0_0.4.0-2_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.4.0-2) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../023-libvorbisenc2_1.3.6-2ubuntu1_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.6-2ubuntu1) ...
# Selecting previously unselected package libvpx6:amd64.
# Preparing to unpack .../024-libvpx6_1.8.2-1ubuntu0.3_amd64.deb ...
# Unpacking libvpx6:amd64 (1.8.2-1ubuntu0.3) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../025-libwavpack1_5.2.0-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libwavpack1:amd64 (5.2.0-1ubuntu0.1) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../026-libwebpmux3_0.6.1-2ubuntu0.20.04.3_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Selecting previously unselected package libx264-155:amd64.
# Preparing to unpack .../027-libx264-155_2%3a0.155.2917+git0a84d98-2_amd64.deb ...
# Unpacking libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libx265-179:amd64.
# Preparing to unpack .../028-libx265-179_3.2.1-1build1_amd64.deb ...
# Unpacking libx265-179:amd64 (3.2.1-1build1) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../029-libxvidcore4_2%3a1.3.7-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.7-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../030-libzvbi-common_0.2.35-17_all.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libzvbi-common (0.2.35-17) ...
# Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../031-libzvbi0_0.2.35-17_amd64.deb ...
# Unpacking libzvbi0:amd64 (0.2.35-17) ...
# Selecting previously unselected package libavcodec58:amd64.
# Preparing to unpack .../032-libavcodec58_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavcodec58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../033-libraw1394-11_2.1.2-1_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-1) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../034-libavc1394-0_0.5.4-5_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-5) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../035-libass9_1%3a0.14.0-2_amd64.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking libass9:amd64 (1:0.14.0-2) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../036-libbluray2_1%3a1.2.0-1_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.2.0-1) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../037-libchromaprint1_1.4.3-3build1_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.4.3-3build1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../038-libgme0_0.6.2-1build1_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.2-1build1) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../039-libmpg123-0_1.25.13-1ubuntu0.2_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.25.13-1ubuntu0.2) ...
# Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../040-libopenmpt0_0.4.11-1build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libopenmpt0:amd64 (0.4.11-1build1) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../041-libssh-gcrypt-4_0.9.3-2ubuntu2.5_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.9.3-2ubuntu2.5) ...
# Selecting previously unselected package libavformat58:amd64.
# Preparing to unpack .../042-libavformat58_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavformat58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../043-libbs2b0_3.1.0+dfsg-2.2build1_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../044-libflite1_2.1-release-3_amd64.deb ...
# Unpacking libflite1:amd64 (2.1-release-3) ...
# Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../045-libserd-0-0_0.30.2-1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libserd-0-0:amd64 (0.30.2-1) ...
# Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../046-libsord-0-0_0.16.4-1_amd64.deb ...
# Unpacking libsord-0-0:amd64 (0.16.4-1) ...
# Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../047-libsratom-0-0_0.6.4-1_amd64.deb ...
# Unpacking libsratom-0-0:amd64 (0.6.4-1) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package liblilv-0-0:amd64.
# Preparing to unpack .../048-liblilv-0-0_0.24.6-1ubuntu0.1_amd64.deb ...
# Unpacking liblilv-0-0:amd64 (0.24.6-1ubuntu0.1) ...
# Selecting previously unselected package libmysofa1:amd64.
# Preparing to unpack .../049-libmysofa1_1.0~dfsg0-1_amd64.deb ...
# Unpacking libmysofa1:amd64 (1.0~dfsg0-1) ...
# Selecting previously unselected package libpostproc55:amd64.
# Preparing to unpack .../050-libpostproc55_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libpostproc55:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../051-libfftw3-double3_3.3.8-2ubuntu1_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu1) ...
# Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../052-libsamplerate0_0.1.9-2_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.1.9-2) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../053-librubberband2_1.8.2-1build1_amd64.deb ...
# Unpacking librubberband2:amd64 (1.8.2-1build1) ...
# Selecting previously unselected package libswscale5:amd64.
# Preparing to unpack .../054-libswscale5_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libswscale5:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libvidstab1.1:amd64.
# Preparing to unpack .../055-libvidstab1.1_1.1.0-2_amd64.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libvidstab1.1:amd64 (1.1.0-2) ...
# Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../056-libnorm1_1.5.8+dfsg2-2build1_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5.8+dfsg2-2build1) ...
# Selecting previously unselected package libpgm-5.2-0:amd64.
# Preparing to unpack .../057-libpgm-5.2-0_5.2.122~dfsg-3ubuntu1_amd64.deb ...
# Unpacking libpgm-5.2-0:amd64 (5.2.122~dfsg-3ubuntu1) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../058-libzmq5_4.3.2-2ubuntu1_amd64.deb ...
# Unpacking libzmq5:amd64 (4.3.2-2ubuntu1) ...
# Selecting previously unselected package libavfilter7:amd64.
# Preparing to unpack .../059-libavfilter7_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavfilter7:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../060-libcaca0_0.99.beta19-2.1ubuntu1.20.04.2_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking libcaca0:amd64 (0.99.beta19-2.1ubuntu1.20.04.2) ...
# Selecting previously unselected package libcdio18:amd64.
# Preparing to unpack .../061-libcdio18_2.0.0-2ubuntu0.2_amd64.deb ...
# Unpacking libcdio18:amd64 (2.0.0-2ubuntu0.2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../062-libcdio-cdda2_10.2+2.0.0-1_amd64.deb ...
# Unpacking libcdio-cdda2:amd64 (10.2+2.0.0-1) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../063-libcdio-paranoia2_10.2+2.0.0-1_amd64.deb ...
# Unpacking libcdio-paranoia2:amd64 (10.2+2.0.0-1) ...
# Selecting previously unselected package libdc1394-22:amd64.
# Preparing to unpack .../064-libdc1394-22_2.2.5-2.1_amd64.deb ...
# Unpacking libdc1394-22:amd64 (2.2.5-2.1) ...
# Selecting previously unselected package libglvnd0:amd64.
# Preparing to unpack .../065-libglvnd0_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libglvnd0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../066-libglapi-mesa_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../067-libx11-xcb1_2%3a1.6.9-2ubuntu1.6_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.6.9-2ubuntu1.6) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../068-libxcb-dri2-0_1.14-2_amd64.deb ...
# Unpacking libxcb-dri2-0:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../069-libxcb-dri3-0_1.14-2_amd64.deb ...
# Unpacking libxcb-dri3-0:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../070-libxcb-glx0_1.14-2_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libxcb-glx0:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../071-libxcb-present0_1.14-2_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../072-libxcb-sync1_1.14-2_amd64.deb ...
# Unpacking libxcb-sync1:amd64 (1.14-2) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../073-libxcb-xfixes0_1.14-2_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.14-2) ...
# Selecting previously unselected package libxshmfence1:amd64.
# Preparing to unpack .../074-libxshmfence1_1.3-1_amd64.deb ...
# Unpacking libxshmfence1:amd64 (1.3-1) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../075-libxxf86vm1_1%3a1.1.4-1build1_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libxxf86vm1:amd64 (1:1.1.4-1build1) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../076-libdrm-amdgpu1_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../077-libpciaccess0_0.16-0ubuntu1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.16-0ubuntu1) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../078-libdrm-intel1_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../079-libdrm-nouveau2_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# Unpacking libdrm-nouveau2:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../080-libdrm-radeon1_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libdrm-radeon1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libllvm12:amd64.
# Preparing to unpack .../081-libllvm12_1%3a12.0.0-3ubuntu1~20.04.5_amd64.deb ...
# Unpacking libllvm12:amd64 (1:12.0.0-3ubuntu1~20.04.5) ...
# Selecting previously unselected package libsensors-config.
# Preparing to unpack .../082-libsensors-config_1%3a3.6.0-2ubuntu1.1_all.deb ...
# Unpacking libsensors-config (1:3.6.0-2ubuntu1.1) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libsensors5:amd64.
# Preparing to unpack .../083-libsensors5_1%3a3.6.0-2ubuntu1.1_amd64.deb ...
# Unpacking libsensors5:amd64 (1:3.6.0-2ubuntu1.1) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../084-libvulkan1_1.2.131.2-1_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.2.131.2-1) ...
# Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../085-libgl1-mesa-dri_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libgl1-mesa-dri:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libglx-mesa0:amd64.
# Preparing to unpack .../086-libglx-mesa0_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libglx-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libglx0:amd64.
# Preparing to unpack .../087-libglx0_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libglx0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libgl1:amd64.
# Preparing to unpack .../088-libgl1_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../089-libiec61883-0_1.2.0-3_amd64.deb ...
# Unpacking libiec61883-0:amd64 (1.2.0-3) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../090-libjack-jackd2-0_1.9.12~dfsg-2ubuntu2_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libjack-jackd2-0:amd64 (1.9.12~dfsg-2ubuntu2) ...
# Selecting previously unselected package libopenal-data.
# Preparing to unpack .../091-libopenal-data_1%3a1.19.1-1_all.deb ...
# Unpacking libopenal-data (1:1.19.1-1) ...
# Selecting previously unselected package libsndio7.0:amd64.
# Preparing to unpack .../092-libsndio7.0_1.5.0-3_amd64.deb ...
# Unpacking libsndio7.0:amd64 (1.5.0-3) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../093-libopenal1_1%3a1.19.1-1_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.19.1-1) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../094-libasyncns0_0.8-6_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../095-libflac8_1.3.3-1ubuntu0.2_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libflac8:amd64 (1.3.3-1ubuntu0.2) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../096-libsndfile1_1.0.28-7ubuntu0.3_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.28-7ubuntu0.3) ...
# Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../097-libpulse0_1%3a13.99.1-1ubuntu3.13_amd64.deb ...
# Unpacking libpulse0:amd64 (1:13.99.1-1ubuntu3.13) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../098-libwayland-client0_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-client0:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-cursor0:amd64.
# Preparing to unpack .../099-libwayland-cursor0_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-cursor0:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-egl1:amd64.
# Preparing to unpack .../100-libwayland-egl1_1.18.0-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libwayland-egl1:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libxcursor1:amd64.
# Preparing to unpack .../101-libxcursor1_1%3a1.2.0-2_amd64.deb ...
# Unpacking libxcursor1:amd64 (1:1.2.0-2) ...
# Selecting previously unselected package libxi6:amd64.
# Preparing to unpack .../102-libxi6_2%3a1.7.10-0ubuntu1_amd64.deb ...
# Unpacking libxi6:amd64 (2:1.7.10-0ubuntu1) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libxkbcommon0:amd64.
# Preparing to unpack .../103-libxkbcommon0_0.10.0-1_amd64.deb ...
# Unpacking libxkbcommon0:amd64 (0.10.0-1) ...
# Selecting previously unselected package libxrandr2:amd64.
# Preparing to unpack .../104-libxrandr2_2%3a1.5.2-0ubuntu1_amd64.deb ...
# Unpacking libxrandr2:amd64 (2:1.5.2-0ubuntu1) ...
# Selecting previously unselected package libxss1:amd64.
# Preparing to unpack .../105-libxss1_1%3a1.2.3-1_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libxss1:amd64 (1:1.2.3-1) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../106-libsdl2-2.0-0_2.0.10+dfsg1-3_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.10+dfsg1-3) ...
# Selecting previously unselected package libxcb-shape0:amd64.
# Preparing to unpack .../107-libxcb-shape0_1.14-2_amd64.deb ...
# Unpacking libxcb-shape0:amd64 (1.14-2) ...
# 7Progress: [ 43%] [#########################.................................] 8Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../108-libxv1_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv1:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libavdevice58:amd64.
# Preparing to unpack .../109-libavdevice58_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavdevice58:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libavresample4:amd64.
# Preparing to unpack .../110-libavresample4_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking libavresample4:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../111-ffmpeg_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking ffmpeg (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libigdgmm11:amd64.
# Preparing to unpack .../112-libigdgmm11_20.1.1+ds1-1_amd64.deb ...
# Unpacking libigdgmm11:amd64 (20.1.1+ds1-1) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package intel-media-va-driver:amd64.
# Preparing to unpack .../113-intel-media-va-driver_20.1.1+dfsg1-1_amd64.deb ...
# Unpacking intel-media-va-driver:amd64 (20.1.1+dfsg1-1) ...
# Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../114-libaacs0_0.9.0-2_amd64.deb ...
# Unpacking libaacs0:amd64 (0.9.0-2) ...
# Selecting previously unselected package libbdplus0:amd64.
# Preparing to unpack .../115-libbdplus0_0.1.2-3_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libbdplus0:amd64 (0.1.2-3) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../116-libgdk-pixbuf2.0-bin_2.40.0+dfsg-3ubuntu0.5_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.40.0+dfsg-3ubuntu0.5) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../117-librsvg2-common_2.48.9-1ubuntu0.20.04.4_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package libxcb-randr0:amd64.
# Preparing to unpack .../118-libxcb-randr0_1.14-2_amd64.deb ...
# Unpacking libxcb-randr0:amd64 (1.14-2) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../119-mesa-va-drivers_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking mesa-va-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../120-mesa-vdpau-drivers_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# 7Progress: [ 48%] [###########################...............................] 8Unpacking mesa-vdpau-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../121-mesa-vulkan-drivers_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../122-i965-va-driver_2.4.0-0ubuntu1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.4.0-0ubuntu1) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../123-va-driver-all_2.7.0-2_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.7.0-2) ...
# Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../124-vdpau-driver-all_1.3-1ubuntu2_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.3-1ubuntu2) ...
# Setting up libgme0:amd64 (0.6.2-1build1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libssh-gcrypt-4:amd64 (0.9.3-2ubuntu2.5) ...
# Setting up libxcb-dri3-0:amd64 (1.14-2) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libx11-xcb1:amd64 (2:1.6.9-2ubuntu1.6) ...
# Setting up libpciaccess0:amd64 (0.16-0ubuntu1) ...
# Setting up libraw1394-11:amd64 (2.1.2-1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libdrm-nouveau2:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Setting up libmpg123-0:amd64 (1.25.13-1ubuntu0.2) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libxcb-xfixes0:amd64 (1.14-2) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1.1ubuntu1.20.04.1) ...
# Setting up libshine3:amd64 (3.1.1-2) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libcaca0:amd64 (0.99.beta19-2.1ubuntu1.20.04.2) ...
# Setting up libxi6:amd64 (2:1.7.10-0ubuntu1) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libtwolame0:amd64 (0.4.0-2) ...
# Setting up libgsm1:amd64 (1.0.18-2) ...
# Setting up libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libx265-179:amd64 (3.2.1-1build1) ...
# Setting up libsoxr0:amd64 (0.1.3-2build1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libdrm-radeon1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Setting up libglvnd0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libxcb-glx0:amd64 (1.14-2) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libaom0:amd64 (1.0.0.errata1-3+deb11u1ubuntu0.1) ...
# Setting up libdrm-intel1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libgdk-pixbuf2.0-common (2.40.0+dfsg-3ubuntu0.5) ...
# Setting up libnorm1:amd64 (1.5.8+dfsg2-2build1) ...
# Setting up libmysofa1:amd64 (1.0~dfsg0-1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libxcb-shape0:amd64 (1.14-2) ...
# Setting up libsensors-config (1:3.6.0-2ubuntu1.1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libdc1394-22:amd64 (2.2.5-2.1) ...
# Setting up libcdio18:amd64 (2.0.0-2ubuntu0.2) ...
# Setting up libxvidcore4:amd64 (2:1.3.7-1) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libxxf86vm1:amd64 (1:1.1.4-1build1) ...
# Setting up libsnappy1v5:amd64 (1.1.8-1build1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libflac8:amd64 (1.3.3-1ubuntu0.2) ...
# Setting up libxcb-present0:amd64 (1.14-2) ...
# Setting up libass9:amd64 (1:0.14.0-2) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libva2:amd64 (2.7.0-2) ...
# Setting up libigdgmm11:amd64 (20.1.1+ds1-1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libxfixes3:amd64 (1:5.0.3-2) ...
# Setting up libxcb-sync1:amd64 (1.14-2) ...
# Setting up libcodec2-0.9:amd64 (0.9.2-2) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libgdk-pixbuf2.0-0:amd64 (2.40.0+dfsg-3ubuntu0.5) ...
# Setting up libllvm12:amd64 (1:12.0.0-3ubuntu1~20.04.5) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libopus0:amd64 (1.3.1-0ubuntu1) ...
# Setting up intel-media-va-driver:amd64 (20.1.1+dfsg1-1) ...
# Setting up libxv1:amd64 (2:1.0.11-1) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libxrandr2:amd64 (2:1.5.2-0ubuntu1) ...
# Setting up libsensors5:amd64 (1:3.6.0-2ubuntu1.1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libaacs0:amd64 (0.9.0-2) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu1) ...
# Setting up libglapi-mesa:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libvulkan1:amd64 (1.2.131.2-1) ...
# Setting up libsndio7.0:amd64 (1.5.0-3) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libxcb-dri2-0:amd64 (1.14-2) ...
# Setting up libbdplus0:amd64 (0.1.2-3) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libflite1:amd64 (2.1-release-3) ...
# Setting up libva-drm2:amd64 (2.7.0-2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# Setting up libasyncns0:amd64 (0.8-6) ...
# Setting up libxshmfence1:amd64 (1.3-1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libvpx6:amd64 (1.8.2-1ubuntu0.3) ...
# Setting up libgdk-pixbuf2.0-bin (2.40.0+dfsg-3ubuntu0.5) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libvdpau1:amd64 (1.3-1ubuntu2) ...
# Setting up libwavpack1:amd64 (5.2.0-1ubuntu0.1) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libxcb-randr0:amd64 (1.14-2) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu2) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libopenal-data (1:1.19.1-1) ...
# Setting up libcairo-gobject2:amd64 (1.16.0-4ubuntu1) ...
# Setting up libwayland-egl1:amd64 (1.18.0-1ubuntu0.1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libxss1:amd64 (1:1.2.3-1) ...
# Setting up libbluray2:amd64 (1:1.2.0-1) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libsamplerate0:amd64 (0.1.9-2) ...
# Setting up libva-x11-2:amd64 (2.7.0-2) ...
# Setting up libwebpmux3:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libopenmpt0:amd64 (0.4.11-1build1) ...
# Setting up libzvbi-common (0.2.35-17) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libmp3lame0:amd64 (3.100-3) ...
# Setting up i965-va-driver:amd64 (2.4.0-0ubuntu1) ...
# Setting up libvorbisenc2:amd64 (1.3.6-2ubuntu1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libpgm-5.2-0:amd64 (5.2.122~dfsg-3ubuntu1) ...
# Setting up libiec61883-0:amd64 (1.2.0-3) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libserd-0-0:amd64 (0.30.2-1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Setting up libxkbcommon0:amd64 (0.10.0-1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libwayland-client0:amd64 (1.18.0-1ubuntu0.1) ...
# Setting up libavc1394-0:amd64 (0.5.4-5) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up mesa-vulkan-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up mesa-vdpau-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libzvbi0:amd64 (0.2.35-17) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libzmq5:amd64 (4.3.2-2ubuntu1) ...
# Setting up libcdio-cdda2:amd64 (10.2+2.0.0-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libcdio-paranoia2:amd64 (10.2+2.0.0-1) ...
# Setting up libxcursor1:amd64 (1:1.2.0-2) ...
# Setting up libgl1-mesa-dri:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libopenal1:amd64 (1:1.19.1-1) ...
# Setting up libavutil56:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up librsvg2-2:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Setting up libpostproc55:amd64 (7:4.2.7-0ubuntu0.1) ...
# Setting up librsvg2-common:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up librubberband2:amd64 (1.8.2-1build1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2ubuntu2) ...
# Setting up vdpau-driver-all:amd64 (1.3-1ubuntu2) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libsord-0-0:amd64 (0.16.4-1) ...
# Setting up libwayland-cursor0:amd64 (1.18.0-1ubuntu0.1) ...
# Setting up libsratom-0-0:amd64 (0.6.4-1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libswscale5:amd64 (7:4.2.7-0ubuntu0.1) ...
# Setting up libsndfile1:amd64 (1.0.28-7ubuntu0.3) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up mesa-va-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up liblilv-0-0:amd64 (0.24.6-1ubuntu0.1) ...
# Setting up libglx-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libglx0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libpulse0:amd64 (1:13.99.1-1ubuntu3.13) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libswresample3:amd64 (7:4.2.7-0ubuntu0.1) ...
# Setting up libavresample4:amd64 (7:4.2.7-0ubuntu0.1) ...
# Setting up libgl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up va-driver-all:amd64 (2.7.0-2) ...
# Setting up libavcodec58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libsdl2-2.0-0:amd64 (2.0.10+dfsg1-3) ...
# Setting up libchromaprint1:amd64 (1.4.3-3build1) ...
# Setting up libavformat58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libavfilter7:amd64 (7:4.2.7-0ubuntu0.1) ...
# Setting up libavdevice58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up ffmpeg (7:4.2.7-0ubuntu0.1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.7) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.40.0+dfsg-3ubuntu0.5) ...
#
# 78
